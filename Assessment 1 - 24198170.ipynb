# %% [markdown]
# # Class assessment [Mohd Nizam Nasir Shaikh] {24198170}

# %%
#Q1-1
portfolios = [{"Client_id" : 1, "Asset_type" : "AAPL", "Value_usd" : 254.43, "is_high_risk" : True},
              {"Client_id" : 2, "Asset_type" : "MSFT", "Value_usd" : 509.23, "is_high_risk" : True},
              {"Client_id" : 3, "Asset_type" : "ETH", "Value_usd" : 3331.31, "is_high_risk" : False}]

# %%
portfolios
# Out:
# [{'Client_id': 1,
#   'Asset_type': 'AAPL',
#   'Value_usd': 254.43,
#   'is_high_risk': True},
#  {'Client_id': 2,
#   'Asset_type': 'MSFT',
#   'Value_usd': 509.23,
#   'is_high_risk': True},
#  {'Client_id': 3,
#   'Asset_type': 'ETH',
#   'Value_usd': 3331.31,
#   'is_high_risk': False}]

# %%
#Q1.2 & 3 & 4
portfolios = [{"Client_id" : 1, "Asset_type" : "AAPL", "Value_usd" : 254.43, "is_high_risk" : True}, \
              {"Client_id" : 2, "Asset_type" : "MSFT", "Value_usd" : 509.23, "is_high_risk" : True}, \
              {"Client_id" : 3, "Asset_type" : "ETH", "Value_usd" : 3331.31, "is_high_risk" : False}]
for i in portfolios:
    if i["is_high_risk"]:
        new_value = i["Value_usd"]*0.90
        print(f"Client_id is {i["Client_id"]} and New_Calculated_Value {new_value:}")
    else:
        new_value = i["Value_usd"]*0.95
        print(f"Client_id is {i["Client_id"]} and New_Calculated_Value {new_value:}")
# Out:
# Client_id is 1 and New_Calculated_Value 228.98700000000002
# Client_id is 2 and New_Calculated_Value 458.307
# Client_id is 3 and New_Calculated_Value 3164.7445

# %%
#Q-2.1
import pandas as pd
df_SBC = pd.read_csv("stocks.csv")
df_SBC.head()
# Out:
#   Ticker        Date        Open        High         Low       Close  \
# 0   AAPL  07/02/2023  150.639999  155.229996  150.639999  154.649994
# 1   MSFT  07/02/2023  260.529999  268.769989  260.079987  267.559998
# 2   NFLX  07/02/2023  358.510010  364.179993  354.179993  362.950012
# 3   GOOG  07/02/2023  103.629997  108.669998  103.547996  108.040001
# 4   AAPL  08/02/2023  153.880005  154.580002  151.169998  151.919998
#
#     Adj Close    Volume
# 0  154.414230  83322600
# 1  266.891510  50841400
# 2  362.950012   6289400
# 3  108.040001  33738800
# 4  151.688400  64120100

# %%
df_SBC.columns
# Out:
# Index(['Ticker', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume'],
#       dtype='object')

# %%
df_SBC.dtypes
# Out:
# Ticker        object
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Q-2.2
df_SBC.isnull().sum()
# Out:
# Ticker       0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Q-2.3
df_SBC["Date"] = pd.to_datetime(df_SBC["Date"], dayfirst=True)
df_SBC
# Out:
#     Ticker       Date        Open        High         Low       Close  \
# 0     AAPL 2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     MSFT 2023-02-07  260.529999  268.769989  260.079987  267.559998
# 2     NFLX 2023-02-07  358.510010  364.179993  354.179993  362.950012
# 3     GOOG 2023-02-07  103.629997  108.669998  103.547996  108.040001
# 4     AAPL 2023-02-08  153.880005  154.580002  151.169998  151.919998
# ..     ...        ...         ...         ...         ...         ...
# 243   GOOG 2023-05-04  106.160004  106.300003  104.699997  105.209999
# 244   AAPL 2023-05-05  170.979996  174.300003  170.759995  173.570007
# 245   MSFT 2023-05-05  305.720001  311.970001  304.269989  310.649994
# 246   NFLX 2023-05-05  323.609985  324.149994  319.440002  322.760010
# 247   GOOG 2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close     Volume
# 0    154.414230   83322600
# 1    266.891510   50841400
# 2    362.950012    6289400
# ...

# %%
#Q-3.1
df_SBC["Daily_Change"] = df_SBC["Close"] - df_SBC["Open"]
df_SBC
# Out:
#     Ticker       Date        Open        High         Low       Close  \
# 0     AAPL 2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     MSFT 2023-02-07  260.529999  268.769989  260.079987  267.559998
# 2     NFLX 2023-02-07  358.510010  364.179993  354.179993  362.950012
# 3     GOOG 2023-02-07  103.629997  108.669998  103.547996  108.040001
# 4     AAPL 2023-02-08  153.880005  154.580002  151.169998  151.919998
# ..     ...        ...         ...         ...         ...         ...
# 243   GOOG 2023-05-04  106.160004  106.300003  104.699997  105.209999
# 244   AAPL 2023-05-05  170.979996  174.300003  170.759995  173.570007
# 245   MSFT 2023-05-05  305.720001  311.970001  304.269989  310.649994
# 246   NFLX 2023-05-05  323.609985  324.149994  319.440002  322.760010
# 247   GOOG 2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close     Volume  Daily_Change
# 0    154.414230   83322600      4.009995
# 1    266.891510   50841400      7.029999
# ...

# %%
#Q-3.2
monthly_groupby = df_SBC.groupby(df_SBC["Date"].dt.month)[["Open","Close"]].mean()
print(monthly_groupby)
# Out:
#             Open       Close
# Date
# 2     213.281234  212.745833
# 3     207.661956  208.217283
# 4     223.092171  223.444737
# 5     226.286999  225.605748

# %%
#Q-3.3
df_SBC
# Out:
#     Ticker       Date        Open        High         Low       Close  \
# 0     AAPL 2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     MSFT 2023-02-07  260.529999  268.769989  260.079987  267.559998
# 2     NFLX 2023-02-07  358.510010  364.179993  354.179993  362.950012
# 3     GOOG 2023-02-07  103.629997  108.669998  103.547996  108.040001
# 4     AAPL 2023-02-08  153.880005  154.580002  151.169998  151.919998
# ..     ...        ...         ...         ...         ...         ...
# 243   GOOG 2023-05-04  106.160004  106.300003  104.699997  105.209999
# 244   AAPL 2023-05-05  170.979996  174.300003  170.759995  173.570007
# 245   MSFT 2023-05-05  305.720001  311.970001  304.269989  310.649994
# 246   NFLX 2023-05-05  323.609985  324.149994  319.440002  322.760010
# 247   GOOG 2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close     Volume  Daily_Change
# 0    154.414230   83322600      4.009995
# 1    266.891510   50841400      7.029999
# ...
